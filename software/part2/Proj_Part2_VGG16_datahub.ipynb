# %%
import argparse
import os
import time
import shutil
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms

# Add parent directory to path to import models if needed, though we will define custom classes here
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from models.quant_layer import weight_quantize_fn, act_quantization

global best_prec
use_gpu = torch.cuda.is_available()
print(f'Using GPU: {use_gpu}')
# Out:
# Using GPU: True

# %% [markdown]
# ### Model Definition
#
# Here we define the custom VGG model with:
# 1. **2-bit Activation** and **4-bit Weight** quantization.
# 2. A specific layer (around 27th) squeezed to **16 channels** with **Batch Normalization removed**.

# %%
class QuantConv2d_Custom(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=False, a_bit=2, w_bit=4):
        super(QuantConv2d_Custom, self).__init__(in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias)
        self.layer_type = 'QuantConv2d_Custom'
        self.w_bit = w_bit 
        self.a_bit = a_bit
        self.weight_quant = weight_quantize_fn(w_bit=w_bit)
        self.act_alq = act_quantization(a_bit)
        self.act_alpha = torch.nn.Parameter(torch.tensor(8.0))
        self.weight_q  = torch.nn.Parameter(torch.zeros([out_channels, in_channels, kernel_size, kernel_size]))
        self.is_quantized = False # Flag to track if quantization has happened
        
    def forward(self, x):
        weight_q = self.weight_quant(self.weight)       
        self.weight_q = torch.nn.Parameter(weight_q) # Store quantized weight for verification
        self.is_quantized = True
        x = self.act_alq(x, self.act_alpha)
        return F.conv2d(x, weight_q, self.bias, self.stride, self.padding, self.dilation, self.groups)
    
    def show_params(self):
        wgt_alpha = round(self.weight_quant.wgt_alpha.data.item(), 3)
        act_alpha = round(self.act_alpha.data.item(), 3)
        print('clipping threshold weight alpha: {:2f}, activation alpha: {:2f}'.format(wgt_alpha, act_alpha))

# %%
# Modified configuration for VGG16
# Original: [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M']
# We modify the block after the 3rd 'M' (MaxPool). Input to this block is 256.
# Original Block: 512, 512, 512
# Modified Block: 16, '16_no_bn', 512
# 1. Conv(256 -> 16) -> BN -> ReLU
# 2. Conv(16 -> 16) -> ReLU (No BN) [Target Layer]
# 3. Conv(16 -> 512) -> BN -> ReLU

cfg_custom = {
    'VGG16_HW6': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 16, '16_no_bn', 512, 'M', 512, 512, 512, 'M'],
}

class VGG_quant_Custom(nn.Module):
    def __init__(self, vgg_name='VGG16_HW6', a_bit=2, w_bit=4):
        super(VGG_quant_Custom, self).__init__()
        self.a_bit = a_bit
        self.w_bit = w_bit
        self.features = self._make_layers(cfg_custom[vgg_name])
        self.classifier = nn.Linear(512, 10)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            elif x == 'F': 
                # 1st layer usually high precision or standard, keeping standard Conv2d
                layers += [nn.Conv2d(in_channels, 64, kernel_size=3, padding=1, bias=False),
                           nn.BatchNorm2d(64),
                           nn.ReLU(inplace=True)]
                in_channels = 64
            elif isinstance(x, str) and '_no_bn' in x:
                # Special case: No BN layer
                out_ch = int(x.replace('_no_bn', ''))
                layers += [QuantConv2d_Custom(in_channels, out_ch, kernel_size=3, padding=1, a_bit=self.a_bit, w_bit=self.w_bit),
                           nn.ReLU(inplace=True)]
                in_channels = out_ch
            else:
                # Standard Quantized Layer
                layers += [QuantConv2d_Custom(in_channels, x, kernel_size=3, padding=1, a_bit=self.a_bit, w_bit=self.w_bit),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)

    def show_params(self):
        for m in self.modules():
            if isinstance(m, QuantConv2d_Custom):
                m.show_params()

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def accuracy(output, target, topk=(1,)):
    """Computes the precision@k for the specified values of k"""
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0)
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

def save_checkpoint(state, is_best, fdir):
    filepath = os.path.join(fdir, 'checkpoint.pth')
    torch.save(state, filepath)
    if is_best:
        shutil.copyfile(filepath, os.path.join(fdir, 'model_best.pth.tar'))

def adjust_learning_rate(optimizer, epoch):
    """For resnet, the lr starts from 0.1, and is divided by 10 at 80 and 120 epochs"""
    adjust_list = [150, 225]
    if epoch in adjust_list:
        for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr'] * 0.1

# %%
def train(trainloader, model, criterion, optimizer, epoch, print_freq=100):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()

    model.train()

    end = time.time()
    for i, (input, target) in enumerate(trainloader):
        # measure data loading time
        data_time.update(time.time() - end)

        input, target = input.cuda(), target.cuda()

        # compute output
        output = model(input)
        loss = criterion(output, target)

        # measure accuracy and record loss
        prec = accuracy(output, target)[0]
        losses.update(loss.item(), input.size(0))
        top1.update(prec.item(), input.size(0))

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % print_freq == 0:
            print('Epoch: [{0}][{1}/{2}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Prec {top1.val:.3f}% ({top1.avg:.3f}%)'.format(
                   epoch, i, len(trainloader), batch_time=batch_time,
                   data_time=data_time, loss=losses, top1=top1))

def validate(val_loader, model, criterion, print_freq=100):
    batch_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    end = time.time()
    with torch.no_grad():
        for i, (input, target) in enumerate(val_loader):
            input, target = input.cuda(), target.cuda()

            # compute output
            output = model(input)
            loss = criterion(output, target)

            # measure accuracy and record loss
            prec = accuracy(output, target)[0]
            losses.update(loss.item(), input.size(0))
            top1.update(prec.item(), input.size(0))

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            if i % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'Prec {top1.val:.3f}% ({top1.avg:.3f}%)'.format(
                   i, len(val_loader), batch_time=batch_time, loss=losses,
                   top1=top1))

    print(' * Prec {top1.avg:.3f}% '.format(top1=top1))
    return top1.avg

# %%
# Hyperparameters
batch_size = 128
lr = 0.1
weight_decay = 1e-4
epochs = 250
print_freq = 100
model_name = "VGG16_HW6_2bit_act_4bit_wgt"

print('=> Building model...')
model = VGG_quant_Custom(vgg_name='VGG16_HW6', a_bit=2, w_bit=4)

if use_gpu:
    model.cuda()
    criterion = nn.CrossEntropyLoss().cuda()
else:
    criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)

# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

print('=> Loading Data...')
normalize = transforms.Normalize(mean=[0.491, 0.482, 0.447], std=[0.247, 0.243, 0.262])

# Ensure data path is correct. If running in software/hw/, data might be in ../data or ./data
# Adjust root as necessary
train_dataset = torchvision.datasets.CIFAR10(
    root='../data',
    train=True,
    download=True,
    transform=transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

test_dataset = torchvision.datasets.CIFAR10(
    root='../data',
    train=False,
    download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ]))
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Results Directory
if not os.path.exists('../result'):
    os.makedirs('../result')
fdir = '../result/'+str(model_name)
if not os.path.exists(fdir):
    os.makedirs(fdir)
# Out:
# => Building model...
# => Loading Data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
best_prec = 0
for epoch in range(0, epochs):
    adjust_learning_rate(optimizer, epoch)
    print(f"Epoch {epoch} started...")
    train(trainloader, model, criterion, optimizer, epoch, print_freq)
    # scheduler.step()
    
    print("Validation starts")
    prec = validate(testloader, model, criterion, print_freq)

    is_best = prec > best_prec
    best_prec = max(prec, best_prec)
    print('best acc: {:1f}'.format(best_prec))
    
    save_checkpoint({
        'epoch': epoch + 1,
        'state_dict': model.state_dict(),
        'best_prec': best_prec,
        'optimizer': optimizer.state_dict(),
    }, is_best, fdir)
# Out:
# Epoch 0 started...
# Epoch: [0][0/391]	Time 0.626 (0.626)	Data 0.244 (0.244)	Loss 2.6221 (2.6221)	Prec 8.594% (8.594%)
# Epoch: [0][100/391]	Time 0.034 (0.042)	Data 0.001 (0.005)	Loss 2.2834 (3.6790)	Prec 15.625% (12.639%)
# Epoch: [0][200/391]	Time 0.035 (0.038)	Data 0.001 (0.003)	Loss 2.2727 (2.9649)	Prec 12.500% (13.930%)
# Epoch: [0][300/391]	Time 0.035 (0.037)	Data 0.001 (0.002)	Loss 2.2025 (2.7222)	Prec 16.406% (14.156%)
# Validation starts
# Test: [0/79]	Time 0.098 (0.098)	Loss 2.1985 (2.1985)	Prec 13.281% (13.281%)
#  * Prec 14.190%
# best acc: 14.190000
# Epoch 1 started...
# Epoch: [1][0/391]	Time 0.214 (0.214)	Data 0.191 (0.191)	Loss 2.2615 (2.2615)	Prec 15.625% (15.625%)
# Epoch: [1][100/391]	Time 0.035 (0.036)	Data 0.002 (0.003)	Loss 2.2034 (2.2278)	Prec 11.719% (14.395%)
# Epoch: [1][200/391]	Time 0.034 (0.036)	Data 0.001 (0.003)	Loss 2.2426 (2.2231)	Prec 11.719% (14.498%)
# Epoch: [1][300/391]	Time 0.034 (0.035)	Data 0.001 (0.002)	Loss 2.2225 (2.2219)	Prec 14.062% (14.761%)
# Validation starts
# Test: [0/79]	Time 0.230 (0.230)	Loss 2.1997 (2.1997)	Prec 11.719% (11.719%)
#  * Prec 14.990%
# best acc: 14.990000
# Epoch 2 started...
# Epoch: [2][0/391]	Time 0.228 (0.228)	Data 0.203 (0.203)	Loss 2.2260 (2.2260)	Prec 17.188% (17.188%)
# Epoch: [2][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 2.1759 (2.2115)	Prec 13.281% (15.548%)
# Epoch: [2][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.2337 (2.2137)	Prec 9.375% (15.264%)
# Epoch: [2][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 2.2293 (2.2135)	Prec 17.969% (15.160%)
# Validation starts
# Test: [0/79]	Time 0.245 (0.245)	Loss 2.2034 (2.2034)	Prec 14.062% (14.062%)
#  * Prec 16.310%
# best acc: 16.310000
# Epoch 3 started...
# Epoch: [3][0/391]	Time 0.301 (0.301)	Data 0.276 (0.276)	Loss 2.1880 (2.1880)	Prec 15.625% (15.625%)
# Epoch: [3][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.1921 (2.2091)	Prec 14.062% (15.749%)
# Epoch: [3][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 2.2831 (2.2056)	Prec 13.281% (15.843%)
# Epoch: [3][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 2.2268 (2.2039)	Prec 13.281% (15.861%)
# Validation starts
# Test: [0/79]	Time 0.151 (0.151)	Loss 2.2189 (2.2189)	Prec 14.844% (14.844%)
#  * Prec 16.460%
# best acc: 16.460000
# Epoch 4 started...
# Epoch: [4][0/391]	Time 0.314 (0.314)	Data 0.287 (0.287)	Loss 2.2397 (2.2397)	Prec 15.625% (15.625%)
# Epoch: [4][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.2443 (2.1893)	Prec 16.406% (16.391%)
# Epoch: [4][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 2.1917 (2.1934)	Prec 14.844% (16.348%)
# Epoch: [4][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.2018 (2.1937)	Prec 13.281% (16.219%)
# Validation starts
# Test: [0/79]	Time 0.239 (0.239)	Loss 2.1939 (2.1939)	Prec 21.094% (21.094%)
#  * Prec 17.010%
# best acc: 17.010000
# Epoch 5 started...
# Epoch: [5][0/391]	Time 0.331 (0.331)	Data 0.308 (0.308)	Loss 2.2206 (2.2206)	Prec 14.844% (14.844%)
# Epoch: [5][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.1110 (2.1917)	Prec 16.406% (15.973%)
# Epoch: [5][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 2.3181 (2.1919)	Prec 14.062% (16.111%)
# Epoch: [5][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.1438 (2.1890)	Prec 24.219% (16.440%)
# Validation starts
# Test: [0/79]	Time 0.231 (0.231)	Loss 2.1544 (2.1544)	Prec 24.219% (24.219%)
#  * Prec 19.120%
# best acc: 19.120000
# Epoch 6 started...
# Epoch: [6][0/391]	Time 0.236 (0.236)	Data 0.209 (0.209)	Loss 2.1691 (2.1691)	Prec 17.969% (17.969%)
# Epoch: [6][100/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 2.1871 (2.1752)	Prec 13.281% (17.744%)
# Epoch: [6][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.1271 (2.1730)	Prec 14.844% (17.747%)
# Epoch: [6][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.1827 (2.1705)	Prec 11.719% (17.914%)
# Validation starts
# Test: [0/79]	Time 0.170 (0.170)	Loss 2.1505 (2.1505)	Prec 24.219% (24.219%)
#  * Prec 19.180%
# best acc: 19.180000
# Epoch 7 started...
# Epoch: [7][0/391]	Time 0.361 (0.361)	Data 0.337 (0.337)	Loss 2.1767 (2.1767)	Prec 21.875% (21.875%)
# Epoch: [7][100/391]	Time 0.035 (0.038)	Data 0.001 (0.005)	Loss 2.1245 (2.1639)	Prec 16.406% (18.193%)
# Epoch: [7][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 2.1536 (2.1565)	Prec 17.188% (18.214%)
# Epoch: [7][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 2.1496 (2.1558)	Prec 24.219% (18.301%)
# Validation starts
# Test: [0/79]	Time 0.126 (0.126)	Loss 2.1263 (2.1263)	Prec 17.969% (17.969%)
#  * Prec 19.560%
# best acc: 19.560000
# Epoch 8 started...
# Epoch: [8][0/391]	Time 0.304 (0.304)	Data 0.281 (0.281)	Loss 2.1797 (2.1797)	Prec 15.625% (15.625%)
# Epoch: [8][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.1662 (2.1582)	Prec 18.750% (17.435%)
# Epoch: [8][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 2.0547 (2.1494)	Prec 29.688% (18.451%)
# Epoch: [8][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.1059 (2.1430)	Prec 18.750% (18.882%)
# Validation starts
# Test: [0/79]	Time 0.152 (0.152)	Loss 2.0645 (2.0645)	Prec 29.688% (29.688%)
#  * Prec 22.110%
# best acc: 22.110000
# Epoch 9 started...
# Epoch: [9][0/391]	Time 0.336 (0.336)	Data 0.309 (0.309)	Loss 2.0928 (2.0928)	Prec 24.219% (24.219%)
# Epoch: [9][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.1111 (2.1120)	Prec 24.219% (20.738%)
# Epoch: [9][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 2.0824 (2.1035)	Prec 21.875% (21.063%)
# Epoch: [9][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 2.0477 (2.0873)	Prec 21.875% (21.535%)
# Validation starts
# Test: [0/79]	Time 0.131 (0.131)	Loss 2.0535 (2.0535)	Prec 28.906% (28.906%)
#  * Prec 22.890%
# best acc: 22.890000
# Epoch 10 started...
# Epoch: [10][0/391]	Time 0.354 (0.354)	Data 0.321 (0.321)	Loss 2.1187 (2.1187)	Prec 25.000% (25.000%)
# Epoch: [10][100/391]	Time 0.035 (0.038)	Data 0.001 (0.005)	Loss 2.1012 (2.0359)	Prec 21.875% (24.466%)
# Epoch: [10][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.9076 (2.0274)	Prec 30.469% (23.954%)
# Epoch: [10][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.9300 (2.0182)	Prec 31.250% (23.944%)
# Validation starts
# Test: [0/79]	Time 0.139 (0.139)	Loss 1.9600 (1.9600)	Prec 26.562% (26.562%)
#  * Prec 26.660%
# best acc: 26.660000
# Epoch 11 started...
# Epoch: [11][0/391]	Time 0.281 (0.281)	Data 0.230 (0.230)	Loss 1.9910 (1.9910)	Prec 24.219% (24.219%)
# Epoch: [11][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 2.0250 (1.9484)	Prec 28.906% (26.795%)
# Epoch: [11][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 2.0340 (1.9398)	Prec 21.875% (26.699%)
# Epoch: [11][300/391]	Time 0.036 (0.036)	Data 0.002 (0.002)	Loss 2.0932 (1.9344)	Prec 18.750% (26.890%)
# Validation starts
# Test: [0/79]	Time 0.128 (0.128)	Loss 1.7685 (1.7685)	Prec 35.156% (35.156%)
#  * Prec 28.200%
# best acc: 28.200000
# Epoch 12 started...
# Epoch: [12][0/391]	Time 0.244 (0.244)	Data 0.213 (0.213)	Loss 1.9163 (1.9163)	Prec 28.125% (28.125%)
# Epoch: [12][100/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 1.7927 (1.8799)	Prec 37.500% (28.086%)
# Epoch: [12][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.9296 (1.8685)	Prec 20.312% (28.941%)
# Epoch: [12][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.7922 (1.8574)	Prec 36.719% (29.633%)
# Validation starts
# Test: [0/79]	Time 0.143 (0.143)	Loss 1.7723 (1.7723)	Prec 28.906% (28.906%)
#  * Prec 34.540%
# best acc: 34.540000
# Epoch 13 started...
# Epoch: [13][0/391]	Time 0.246 (0.246)	Data 0.213 (0.213)	Loss 1.7856 (1.7856)	Prec 31.250% (31.250%)
# Epoch: [13][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.7780 (1.7645)	Prec 30.469% (32.843%)
# Epoch: [13][200/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 1.7455 (1.7504)	Prec 25.781% (33.547%)
# Epoch: [13][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.7384 (1.7415)	Prec 36.719% (33.773%)
# Validation starts
# Test: [0/79]	Time 0.138 (0.138)	Loss 1.7179 (1.7179)	Prec 34.375% (34.375%)
#  * Prec 35.850%
# best acc: 35.850000
# Epoch 14 started...
# Epoch: [14][0/391]	Time 0.403 (0.403)	Data 0.376 (0.376)	Loss 1.7432 (1.7432)	Prec 32.031% (32.031%)
# Epoch: [14][100/391]	Time 0.035 (0.039)	Data 0.002 (0.005)	Loss 1.7288 (1.6942)	Prec 30.469% (35.396%)
# Epoch: [14][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.8280 (1.6910)	Prec 28.906% (35.887%)
# Epoch: [14][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.7417 (1.6833)	Prec 39.062% (36.021%)
# Validation starts
# Test: [0/79]	Time 0.140 (0.140)	Loss 1.5829 (1.5829)	Prec 39.844% (39.844%)
#  * Prec 40.470%
# best acc: 40.470000
# Epoch 15 started...
# Epoch: [15][0/391]	Time 0.287 (0.287)	Data 0.262 (0.262)	Loss 1.5826 (1.5826)	Prec 42.969% (42.969%)
# Epoch: [15][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 1.6364 (1.6270)	Prec 37.500% (39.117%)
# Epoch: [15][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.5774 (1.6258)	Prec 42.188% (38.814%)
# Epoch: [15][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.5620 (1.6230)	Prec 40.625% (39.101%)
# Validation starts
# Test: [0/79]	Time 0.213 (0.213)	Loss 1.6606 (1.6606)	Prec 37.500% (37.500%)
#  * Prec 39.920%
# best acc: 40.470000
# Epoch 16 started...
# Epoch: [16][0/391]	Time 0.289 (0.289)	Data 0.263 (0.263)	Loss 1.5877 (1.5877)	Prec 42.969% (42.969%)
# Epoch: [16][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 1.5778 (1.5963)	Prec 46.094% (40.053%)
# Epoch: [16][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.6148 (1.5855)	Prec 41.406% (40.365%)
# Epoch: [16][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.4635 (1.5732)	Prec 45.312% (40.885%)
# Validation starts
# Test: [0/79]	Time 0.230 (0.230)	Loss 1.5066 (1.5066)	Prec 40.625% (40.625%)
#  * Prec 45.040%
# best acc: 45.040000
# Epoch 17 started...
# Epoch: [17][0/391]	Time 0.238 (0.238)	Data 0.214 (0.214)	Loss 1.5004 (1.5004)	Prec 39.844% (39.844%)
# Epoch: [17][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 1.3916 (1.5454)	Prec 48.438% (41.940%)
# Epoch: [17][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.5554 (1.5321)	Prec 36.719% (42.782%)
# Epoch: [17][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 1.4219 (1.5187)	Prec 45.312% (43.599%)
# Validation starts
# Test: [0/79]	Time 0.084 (0.084)	Loss 1.5094 (1.5094)	Prec 48.438% (48.438%)
#  * Prec 42.780%
# best acc: 45.040000
# Epoch 18 started...
# Epoch: [18][0/391]	Time 0.294 (0.294)	Data 0.263 (0.263)	Loss 1.6357 (1.6357)	Prec 40.625% (40.625%)
# Epoch: [18][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 1.4718 (1.4800)	Prec 39.844% (45.699%)
# Epoch: [18][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.5254 (1.4728)	Prec 44.531% (45.748%)
# Epoch: [18][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.2609 (1.4594)	Prec 52.344% (46.299%)
# Validation starts
# Test: [0/79]	Time 0.136 (0.136)	Loss 1.4746 (1.4746)	Prec 47.656% (47.656%)
#  * Prec 47.120%
# best acc: 47.120000
# Epoch 19 started...
# Epoch: [19][0/391]	Time 0.336 (0.336)	Data 0.302 (0.302)	Loss 1.3138 (1.3138)	Prec 49.219% (49.219%)
# Epoch: [19][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 1.4273 (1.4126)	Prec 43.750% (48.182%)
# Epoch: [19][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.2964 (1.4109)	Prec 50.000% (48.235%)
# Epoch: [19][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.3464 (1.4003)	Prec 50.000% (48.513%)
# Validation starts
# Test: [0/79]	Time 0.135 (0.135)	Loss 1.3328 (1.3328)	Prec 50.781% (50.781%)
#  * Prec 49.380%
# best acc: 49.380000
# Epoch 20 started...
# Epoch: [20][0/391]	Time 0.337 (0.337)	Data 0.305 (0.305)	Loss 1.3799 (1.3799)	Prec 47.656% (47.656%)
# Epoch: [20][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 1.3973 (1.3589)	Prec 53.125% (50.317%)
# Epoch: [20][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.2736 (1.3489)	Prec 60.156% (50.653%)
# Epoch: [20][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.3046 (1.3471)	Prec 50.000% (50.867%)
# Validation starts
# Test: [0/79]	Time 0.103 (0.103)	Loss 1.3054 (1.3054)	Prec 53.125% (53.125%)
#  * Prec 49.420%
# best acc: 49.420000
# Epoch 21 started...
# Epoch: [21][0/391]	Time 0.285 (0.285)	Data 0.257 (0.257)	Loss 1.1515 (1.1515)	Prec 55.469% (55.469%)
# Epoch: [21][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 1.3544 (1.3074)	Prec 52.344% (53.017%)
# Epoch: [21][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.2974 (1.2995)	Prec 53.906% (53.467%)
# Epoch: [21][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 1.1700 (1.2929)	Prec 55.469% (53.743%)
# Validation starts
# Test: [0/79]	Time 0.240 (0.240)	Loss 1.2394 (1.2394)	Prec 50.781% (50.781%)
#  * Prec 55.640%
# best acc: 55.640000
# Epoch 22 started...
# Epoch: [22][0/391]	Time 0.217 (0.217)	Data 0.193 (0.193)	Loss 1.1691 (1.1691)	Prec 58.594% (58.594%)
# Epoch: [22][100/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.1939 (1.2269)	Prec 53.906% (55.987%)
# Epoch: [22][200/391]	Time 0.034 (0.036)	Data 0.001 (0.002)	Loss 1.0586 (1.2254)	Prec 61.719% (56.246%)
# Epoch: [22][300/391]	Time 0.035 (0.035)	Data 0.002 (0.002)	Loss 1.2487 (1.2251)	Prec 53.906% (56.375%)
# Validation starts
# Test: [0/79]	Time 0.133 (0.133)	Loss 1.1142 (1.1142)	Prec 60.156% (60.156%)
#  * Prec 57.780%
# best acc: 57.780000
# Epoch 23 started...
# Epoch: [23][0/391]	Time 0.233 (0.233)	Data 0.202 (0.202)	Loss 1.1043 (1.1043)	Prec 62.500% (62.500%)
# Epoch: [23][100/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 1.2175 (1.1720)	Prec 60.156% (58.849%)
# Epoch: [23][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.0919 (1.1705)	Prec 60.156% (58.500%)
# Epoch: [23][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.1594 (1.1678)	Prec 60.156% (58.646%)
# Validation starts
# Test: [0/79]	Time 0.149 (0.149)	Loss 1.0536 (1.0536)	Prec 60.938% (60.938%)
#  * Prec 58.520%
# best acc: 58.520000
# Epoch 24 started...
# Epoch: [24][0/391]	Time 0.382 (0.382)	Data 0.352 (0.352)	Loss 0.9191 (0.9191)	Prec 65.625% (65.625%)
# Epoch: [24][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.9464 (1.1038)	Prec 68.750% (60.458%)
# Epoch: [24][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.0578 (1.1008)	Prec 60.156% (60.829%)
# Epoch: [24][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 1.1365 (1.0962)	Prec 60.156% (61.124%)
# Validation starts
# Test: [0/79]	Time 0.134 (0.134)	Loss 1.0162 (1.0162)	Prec 62.500% (62.500%)
#  * Prec 57.910%
# best acc: 58.520000
# Epoch 25 started...
# Epoch: [25][0/391]	Time 0.279 (0.279)	Data 0.250 (0.250)	Loss 1.1646 (1.1646)	Prec 59.375% (59.375%)
# Epoch: [25][100/391]	Time 0.036 (0.038)	Data 0.001 (0.004)	Loss 0.9270 (1.0657)	Prec 62.500% (62.345%)
# Epoch: [25][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.9415 (1.0524)	Prec 67.969% (63.056%)
# Epoch: [25][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.9137 (1.0416)	Prec 66.406% (63.538%)
# Validation starts
# Test: [0/79]	Time 0.211 (0.211)	Loss 1.0516 (1.0516)	Prec 68.750% (68.750%)
#  * Prec 61.050%
# best acc: 61.050000
# Epoch 26 started...
# Epoch: [26][0/391]	Time 0.358 (0.358)	Data 0.324 (0.324)	Loss 1.1558 (1.1558)	Prec 55.469% (55.469%)
# Epoch: [26][100/391]	Time 0.034 (0.038)	Data 0.001 (0.005)	Loss 1.0416 (1.0145)	Prec 65.625% (64.821%)
# Epoch: [26][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 1.0131 (1.0140)	Prec 58.594% (64.572%)
# Epoch: [26][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.8543 (1.0075)	Prec 71.094% (64.942%)
# Validation starts
# Test: [0/79]	Time 0.086 (0.086)	Loss 0.9179 (0.9179)	Prec 67.188% (67.188%)
#  * Prec 64.960%
# best acc: 64.960000
# Epoch 27 started...
# Epoch: [27][0/391]	Time 0.294 (0.294)	Data 0.268 (0.268)	Loss 0.9087 (0.9087)	Prec 64.062% (64.062%)
# Epoch: [27][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.9840 (0.9779)	Prec 68.750% (66.375%)
# Epoch: [27][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 1.0340 (0.9722)	Prec 67.969% (66.523%)
# Epoch: [27][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.9977 (0.9659)	Prec 64.062% (66.627%)
# Validation starts
# Test: [0/79]	Time 0.138 (0.138)	Loss 0.9279 (0.9279)	Prec 63.281% (63.281%)
#  * Prec 64.090%
# best acc: 64.960000
# Epoch 28 started...
# Epoch: [28][0/391]	Time 0.302 (0.302)	Data 0.276 (0.276)	Loss 0.9094 (0.9094)	Prec 68.750% (68.750%)
# Epoch: [28][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.9952 (0.9449)	Prec 63.281% (67.466%)
# Epoch: [28][200/391]	Time 0.034 (0.036)	Data 0.002 (0.003)	Loss 0.9752 (0.9489)	Prec 65.625% (67.242%)
# Epoch: [28][300/391]	Time 0.033 (0.035)	Data 0.001 (0.002)	Loss 0.6930 (0.9360)	Prec 79.688% (67.730%)
# Validation starts
# Test: [0/79]	Time 0.212 (0.212)	Loss 0.9528 (0.9528)	Prec 66.406% (66.406%)
#  * Prec 65.830%
# best acc: 65.830000
# Epoch 29 started...
# Epoch: [29][0/391]	Time 0.256 (0.256)	Data 0.223 (0.223)	Loss 0.9275 (0.9275)	Prec 64.844% (64.844%)
# Epoch: [29][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.8811 (0.8901)	Prec 67.188% (68.920%)
# Epoch: [29][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.0256 (0.8953)	Prec 60.938% (69.022%)
# Epoch: [29][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 1.0308 (0.8953)	Prec 64.844% (69.126%)
# Validation starts
# Test: [0/79]	Time 0.162 (0.162)	Loss 0.8554 (0.8554)	Prec 65.625% (65.625%)
#  * Prec 69.990%
# best acc: 69.990000
# Epoch 30 started...
# Epoch: [30][0/391]	Time 0.276 (0.276)	Data 0.208 (0.208)	Loss 0.7649 (0.7649)	Prec 71.875% (71.875%)
# Epoch: [30][100/391]	Time 0.036 (0.038)	Data 0.001 (0.003)	Loss 0.7953 (0.8575)	Prec 75.000% (70.645%)
# Epoch: [30][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.8080 (0.8501)	Prec 72.656% (70.864%)
# Epoch: [30][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.9249 (0.8350)	Prec 73.438% (71.351%)
# Validation starts
# Test: [0/79]	Time 0.156 (0.156)	Loss 0.8840 (0.8840)	Prec 67.188% (67.188%)
#  * Prec 67.370%
# best acc: 69.990000
# Epoch 31 started...
# Epoch: [31][0/391]	Time 0.271 (0.271)	Data 0.240 (0.240)	Loss 0.7928 (0.7928)	Prec 71.094% (71.094%)
# Epoch: [31][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.9616 (0.7872)	Prec 64.844% (73.523%)
# Epoch: [31][200/391]	Time 0.034 (0.036)	Data 0.001 (0.003)	Loss 0.9217 (0.7866)	Prec 68.750% (73.305%)
# Epoch: [31][300/391]	Time 0.032 (0.035)	Data 0.001 (0.002)	Loss 0.8140 (0.7910)	Prec 74.219% (73.170%)
# Validation starts
# Test: [0/79]	Time 0.151 (0.151)	Loss 0.7317 (0.7317)	Prec 75.000% (75.000%)
#  * Prec 72.440%
# best acc: 72.440000
# Epoch 32 started...
# Epoch: [32][0/391]	Time 0.286 (0.286)	Data 0.257 (0.257)	Loss 0.6431 (0.6431)	Prec 79.688% (79.688%)
# Epoch: [32][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.7919 (0.7216)	Prec 71.094% (75.309%)
# Epoch: [32][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.5765 (0.7277)	Prec 82.031% (75.400%)
# Epoch: [32][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.7501 (0.7364)	Prec 71.094% (75.125%)
# Validation starts
# Test: [0/79]	Time 0.159 (0.159)	Loss 0.8696 (0.8696)	Prec 67.188% (67.188%)
#  * Prec 72.570%
# best acc: 72.570000
# Epoch 33 started...
# Epoch: [33][0/391]	Time 0.247 (0.247)	Data 0.216 (0.216)	Loss 0.7818 (0.7818)	Prec 75.000% (75.000%)
# Epoch: [33][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.7411 (0.7278)	Prec 71.094% (74.992%)
# Epoch: [33][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.6516 (0.7143)	Prec 78.125% (75.556%)
# Epoch: [33][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.7499 (0.7203)	Prec 75.781% (75.493%)
# Validation starts
# Test: [0/79]	Time 0.148 (0.148)	Loss 0.6393 (0.6393)	Prec 75.000% (75.000%)
#  * Prec 75.430%
# best acc: 75.430000
# Epoch 34 started...
# Epoch: [34][0/391]	Time 0.294 (0.294)	Data 0.234 (0.234)	Loss 0.5165 (0.5165)	Prec 80.469% (80.469%)
# Epoch: [34][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.7822 (0.6806)	Prec 74.219% (76.841%)
# Epoch: [34][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.7092 (0.6852)	Prec 74.219% (76.807%)
# Epoch: [34][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.6260 (0.6882)	Prec 75.781% (76.749%)
# Validation starts
# Test: [0/79]	Time 0.149 (0.149)	Loss 0.7054 (0.7054)	Prec 79.688% (79.688%)
#  * Prec 74.500%
# best acc: 75.430000
# Epoch 35 started...
# Epoch: [35][0/391]	Time 0.297 (0.297)	Data 0.272 (0.272)	Loss 0.8259 (0.8259)	Prec 70.312% (70.312%)
# Epoch: [35][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.5195 (0.6634)	Prec 78.906% (77.529%)
# Epoch: [35][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.5237 (0.6625)	Prec 82.031% (77.686%)
# Epoch: [35][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.7819 (0.6647)	Prec 75.000% (77.668%)
# Validation starts
# Test: [0/79]	Time 0.320 (0.320)	Loss 0.6372 (0.6372)	Prec 82.812% (82.812%)
#  * Prec 76.010%
# best acc: 76.010000
# Epoch 36 started...
# Epoch: [36][0/391]	Time 0.327 (0.327)	Data 0.300 (0.300)	Loss 0.6562 (0.6562)	Prec 78.125% (78.125%)
# Epoch: [36][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.6405 (0.6540)	Prec 79.688% (77.924%)
# Epoch: [36][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6173 (0.6491)	Prec 81.250% (78.074%)
# Epoch: [36][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.6072 (0.6504)	Prec 76.562% (78.055%)
# Validation starts
# Test: [0/79]	Time 0.242 (0.242)	Loss 0.5798 (0.5798)	Prec 79.688% (79.688%)
#  * Prec 77.320%
# best acc: 77.320000
# Epoch 37 started...
# Epoch: [37][0/391]	Time 0.270 (0.270)	Data 0.240 (0.240)	Loss 0.6110 (0.6110)	Prec 76.562% (76.562%)
# Epoch: [37][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.6605 (0.6094)	Prec 82.812% (79.401%)
# Epoch: [37][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.7098 (0.6210)	Prec 73.438% (79.031%)
# Epoch: [37][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.7310 (0.6254)	Prec 75.781% (78.860%)
# Validation starts
# Test: [0/79]	Time 0.143 (0.143)	Loss 0.6276 (0.6276)	Prec 78.125% (78.125%)
#  * Prec 75.860%
# best acc: 77.320000
# Epoch 38 started...
# Epoch: [38][0/391]	Time 0.317 (0.317)	Data 0.289 (0.289)	Loss 0.5423 (0.5423)	Prec 78.906% (78.906%)
# Epoch: [38][100/391]	Time 0.036 (0.038)	Data 0.001 (0.004)	Loss 0.8227 (0.6098)	Prec 75.781% (79.293%)
# Epoch: [38][200/391]	Time 0.037 (0.036)	Data 0.002 (0.003)	Loss 0.5752 (0.6092)	Prec 78.906% (79.380%)
# Epoch: [38][300/391]	Time 0.034 (0.036)	Data 0.002 (0.002)	Loss 0.6724 (0.6104)	Prec 75.000% (79.532%)
# Validation starts
# Test: [0/79]	Time 0.167 (0.167)	Loss 0.6374 (0.6374)	Prec 81.250% (81.250%)
#  * Prec 76.260%
# best acc: 77.320000
# Epoch 39 started...
# Epoch: [39][0/391]	Time 0.255 (0.255)	Data 0.224 (0.224)	Loss 0.5414 (0.5414)	Prec 78.906% (78.906%)
# Epoch: [39][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.5589 (0.6094)	Prec 82.031% (79.811%)
# Epoch: [39][200/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.6740 (0.6059)	Prec 78.125% (79.377%)
# Epoch: [39][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5740 (0.6080)	Prec 82.812% (79.345%)
# Validation starts
# Test: [0/79]	Time 0.237 (0.237)	Loss 0.8930 (0.8930)	Prec 71.094% (71.094%)
#  * Prec 73.010%
# best acc: 77.320000
# Epoch 40 started...
# Epoch: [40][0/391]	Time 0.370 (0.370)	Data 0.344 (0.344)	Loss 0.5575 (0.5575)	Prec 80.469% (80.469%)
# Epoch: [40][100/391]	Time 0.035 (0.038)	Data 0.001 (0.005)	Loss 0.6329 (0.5796)	Prec 78.125% (80.322%)
# Epoch: [40][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6182 (0.5768)	Prec 76.562% (80.500%)
# Epoch: [40][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.6134 (0.5834)	Prec 76.562% (80.264%)
# Validation starts
# Test: [0/79]	Time 0.227 (0.227)	Loss 0.6926 (0.6926)	Prec 78.906% (78.906%)
#  * Prec 77.320%
# best acc: 77.320000
# Epoch 41 started...
# Epoch: [41][0/391]	Time 0.383 (0.383)	Data 0.360 (0.360)	Loss 0.6592 (0.6592)	Prec 76.562% (76.562%)
# Epoch: [41][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.4340 (0.5673)	Prec 83.594% (80.407%)
# Epoch: [41][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.7315 (0.5648)	Prec 76.562% (80.838%)
# Epoch: [41][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.6938 (0.5697)	Prec 70.312% (80.604%)
# Validation starts
# Test: [0/79]	Time 0.145 (0.145)	Loss 0.7572 (0.7572)	Prec 77.344% (77.344%)
#  * Prec 76.630%
# best acc: 77.320000
# Epoch 42 started...
# Epoch: [42][0/391]	Time 0.387 (0.387)	Data 0.353 (0.353)	Loss 0.7565 (0.7565)	Prec 76.562% (76.562%)
# Epoch: [42][100/391]	Time 0.034 (0.039)	Data 0.001 (0.005)	Loss 0.5219 (0.5589)	Prec 82.031% (81.258%)
# Epoch: [42][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6974 (0.5648)	Prec 78.906% (81.258%)
# Epoch: [42][300/391]	Time 0.036 (0.036)	Data 0.001 (0.003)	Loss 0.6382 (0.5573)	Prec 73.438% (81.372%)
# Validation starts
# Test: [0/79]	Time 0.136 (0.136)	Loss 0.5632 (0.5632)	Prec 84.375% (84.375%)
#  * Prec 77.740%
# best acc: 77.740000
# Epoch 43 started...
# Epoch: [43][0/391]	Time 0.311 (0.311)	Data 0.276 (0.276)	Loss 0.6984 (0.6984)	Prec 78.906% (78.906%)
# Epoch: [43][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.6284 (0.5366)	Prec 77.344% (81.714%)
# Epoch: [43][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 0.5537 (0.5362)	Prec 82.031% (81.946%)
# Epoch: [43][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4704 (0.5427)	Prec 79.688% (81.691%)
# Validation starts
# Test: [0/79]	Time 0.149 (0.149)	Loss 0.5517 (0.5517)	Prec 81.250% (81.250%)
#  * Prec 77.700%
# best acc: 77.740000
# Epoch 44 started...
# Epoch: [44][0/391]	Time 0.302 (0.302)	Data 0.272 (0.272)	Loss 0.5509 (0.5509)	Prec 78.906% (78.906%)
# Epoch: [44][100/391]	Time 0.036 (0.038)	Data 0.001 (0.004)	Loss 0.4979 (0.5335)	Prec 84.375% (82.271%)
# Epoch: [44][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6175 (0.5349)	Prec 78.125% (82.167%)
# Epoch: [44][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.6101 (0.5367)	Prec 82.031% (82.156%)
# Validation starts
# Test: [0/79]	Time 0.171 (0.171)	Loss 0.5735 (0.5735)	Prec 78.125% (78.125%)
#  * Prec 80.160%
# best acc: 80.160000
# Epoch 45 started...
# Epoch: [45][0/391]	Time 0.235 (0.235)	Data 0.203 (0.203)	Loss 0.6074 (0.6074)	Prec 77.344% (77.344%)
# Epoch: [45][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.5997 (0.5286)	Prec 81.250% (81.946%)
# Epoch: [45][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5477 (0.5241)	Prec 82.812% (82.140%)
# Epoch: [45][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4018 (0.5209)	Prec 86.719% (82.410%)
# Validation starts
# Test: [0/79]	Time 0.143 (0.143)	Loss 0.7804 (0.7804)	Prec 77.344% (77.344%)
#  * Prec 74.680%
# best acc: 80.160000
# Epoch 46 started...
# Epoch: [46][0/391]	Time 0.224 (0.224)	Data 0.194 (0.194)	Loss 0.5054 (0.5054)	Prec 81.250% (81.250%)
# Epoch: [46][100/391]	Time 0.034 (0.036)	Data 0.002 (0.003)	Loss 0.4666 (0.5269)	Prec 85.938% (82.317%)
# Epoch: [46][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4890 (0.5252)	Prec 82.812% (82.187%)
# Epoch: [46][300/391]	Time 0.034 (0.035)	Data 0.001 (0.002)	Loss 0.5865 (0.5182)	Prec 79.688% (82.480%)
# Validation starts
# Test: [0/79]	Time 0.247 (0.247)	Loss 0.5500 (0.5500)	Prec 77.344% (77.344%)
#  * Prec 80.890%
# best acc: 80.890000
# Epoch 47 started...
# Epoch: [47][0/391]	Time 0.345 (0.345)	Data 0.318 (0.318)	Loss 0.5113 (0.5113)	Prec 82.031% (82.031%)
# Epoch: [47][100/391]	Time 0.035 (0.038)	Data 0.001 (0.005)	Loss 0.4549 (0.5045)	Prec 82.812% (83.184%)
# Epoch: [47][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6107 (0.5053)	Prec 79.688% (82.960%)
# Epoch: [47][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.4864 (0.5062)	Prec 80.469% (82.981%)
# Validation starts
# Test: [0/79]	Time 0.345 (0.345)	Loss 0.4886 (0.4886)	Prec 82.812% (82.812%)
#  * Prec 78.030%
# best acc: 80.890000
# Epoch 48 started...
# Epoch: [48][0/391]	Time 0.444 (0.444)	Data 0.388 (0.388)	Loss 0.3326 (0.3326)	Prec 88.281% (88.281%)
# Epoch: [48][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.4536 (0.4915)	Prec 84.375% (83.718%)
# Epoch: [48][200/391]	Time 0.029 (0.037)	Data 0.002 (0.003)	Loss 0.4870 (0.4955)	Prec 85.938% (83.695%)
# Epoch: [48][300/391]	Time 0.029 (0.036)	Data 0.001 (0.003)	Loss 0.3589 (0.4975)	Prec 85.938% (83.480%)
# Validation starts
# Test: [0/79]	Time 0.146 (0.146)	Loss 0.5040 (0.5040)	Prec 84.375% (84.375%)
#  * Prec 80.120%
# best acc: 80.890000
# Epoch 49 started...
# Epoch: [49][0/391]	Time 0.305 (0.305)	Data 0.275 (0.275)	Loss 0.3444 (0.3444)	Prec 89.062% (89.062%)
# Epoch: [49][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.6885 (0.4807)	Prec 77.344% (84.127%)
# Epoch: [49][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.5827 (0.4921)	Prec 85.156% (83.431%)
# Epoch: [49][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3060 (0.4916)	Prec 88.281% (83.461%)
# Validation starts
# Test: [0/79]	Time 0.116 (0.116)	Loss 0.6286 (0.6286)	Prec 77.344% (77.344%)
#  * Prec 78.970%
# best acc: 80.890000
# Epoch 50 started...
# Epoch: [50][0/391]	Time 0.233 (0.233)	Data 0.201 (0.201)	Loss 0.4683 (0.4683)	Prec 82.031% (82.031%)
# Epoch: [50][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.3503 (0.4819)	Prec 88.281% (83.926%)
# Epoch: [50][200/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.4753 (0.4936)	Prec 86.719% (83.765%)
# Epoch: [50][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4607 (0.4956)	Prec 83.594% (83.770%)
# Validation starts
# Test: [0/79]	Time 0.142 (0.142)	Loss 0.5669 (0.5669)	Prec 81.250% (81.250%)
#  * Prec 81.090%
# best acc: 81.090000
# Epoch 51 started...
# Epoch: [51][0/391]	Time 0.236 (0.236)	Data 0.210 (0.210)	Loss 0.3558 (0.3558)	Prec 89.062% (89.062%)
# Epoch: [51][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6794 (0.4739)	Prec 78.906% (84.398%)
# Epoch: [51][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4028 (0.4797)	Prec 88.281% (84.340%)
# Epoch: [51][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5876 (0.4797)	Prec 81.250% (84.139%)
# Validation starts
# Test: [0/79]	Time 0.111 (0.111)	Loss 0.4174 (0.4174)	Prec 87.500% (87.500%)
#  * Prec 80.840%
# best acc: 81.090000
# Epoch 52 started...
# Epoch: [52][0/391]	Time 0.318 (0.318)	Data 0.245 (0.245)	Loss 0.5396 (0.5396)	Prec 83.594% (83.594%)
# Epoch: [52][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.4612 (0.4516)	Prec 84.375% (84.638%)
# Epoch: [52][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4080 (0.4648)	Prec 85.938% (84.293%)
# Epoch: [52][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5187 (0.4698)	Prec 82.031% (84.258%)
# Validation starts
# Test: [0/79]	Time 0.164 (0.164)	Loss 0.5817 (0.5817)	Prec 82.031% (82.031%)
#  * Prec 79.240%
# best acc: 81.090000
# Epoch 53 started...
# Epoch: [53][0/391]	Time 0.384 (0.384)	Data 0.356 (0.356)	Loss 0.2984 (0.2984)	Prec 89.844% (89.844%)
# Epoch: [53][100/391]	Time 0.035 (0.039)	Data 0.002 (0.005)	Loss 0.4922 (0.4643)	Prec 85.156% (84.313%)
# Epoch: [53][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.5121 (0.4639)	Prec 83.594% (84.313%)
# Epoch: [53][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3604 (0.4606)	Prec 86.719% (84.526%)
# Validation starts
# Test: [0/79]	Time 0.113 (0.113)	Loss 0.5700 (0.5700)	Prec 82.812% (82.812%)
#  * Prec 79.230%
# best acc: 81.090000
# Epoch 54 started...
# Epoch: [54][0/391]	Time 0.343 (0.343)	Data 0.312 (0.312)	Loss 0.3468 (0.3468)	Prec 87.500% (87.500%)
# Epoch: [54][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.4884 (0.4659)	Prec 83.594% (84.468%)
# Epoch: [54][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.6122 (0.4612)	Prec 81.250% (84.581%)
# Epoch: [54][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4727 (0.4638)	Prec 84.375% (84.567%)
# Validation starts
# Test: [0/79]	Time 0.215 (0.215)	Loss 0.4650 (0.4650)	Prec 85.938% (85.938%)
#  * Prec 81.680%
# best acc: 81.680000
# Epoch 55 started...
# Epoch: [55][0/391]	Time 0.260 (0.260)	Data 0.231 (0.231)	Loss 0.4395 (0.4395)	Prec 85.156% (85.156%)
# Epoch: [55][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.4682 (0.4467)	Prec 82.031% (85.149%)
# Epoch: [55][200/391]	Time 0.035 (0.036)	Data 0.002 (0.003)	Loss 0.4842 (0.4455)	Prec 83.594% (85.086%)
# Epoch: [55][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.4774 (0.4445)	Prec 87.500% (85.156%)
# Validation starts
# Test: [0/79]	Time 0.174 (0.174)	Loss 0.4869 (0.4869)	Prec 83.594% (83.594%)
#  * Prec 81.570%
# best acc: 81.680000
# Epoch 56 started...
# Epoch: [56][0/391]	Time 0.297 (0.297)	Data 0.267 (0.267)	Loss 0.3558 (0.3558)	Prec 84.375% (84.375%)
# Epoch: [56][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.3208 (0.4408)	Prec 89.062% (85.303%)
# Epoch: [56][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4647 (0.4513)	Prec 84.375% (84.927%)
# Epoch: [56][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5139 (0.4497)	Prec 83.594% (85.019%)
# Validation starts
# Test: [0/79]	Time 0.138 (0.138)	Loss 0.4861 (0.4861)	Prec 83.594% (83.594%)
#  * Prec 82.350%
# best acc: 82.350000
# Epoch 57 started...
# Epoch: [57][0/391]	Time 0.322 (0.322)	Data 0.299 (0.299)	Loss 0.4531 (0.4531)	Prec 84.375% (84.375%)
# Epoch: [57][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.4925 (0.4324)	Prec 85.938% (85.265%)
# Epoch: [57][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4822 (0.4330)	Prec 86.719% (85.281%)
# Epoch: [57][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4500 (0.4397)	Prec 85.156% (85.154%)
# Validation starts
# Test: [0/79]	Time 0.155 (0.155)	Loss 0.6142 (0.6142)	Prec 78.906% (78.906%)
#  * Prec 80.290%
# best acc: 82.350000
# Epoch 58 started...
# Epoch: [58][0/391]	Time 0.285 (0.285)	Data 0.261 (0.261)	Loss 0.3806 (0.3806)	Prec 84.375% (84.375%)
# Epoch: [58][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.6425 (0.4295)	Prec 80.469% (85.319%)
# Epoch: [58][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4588 (0.4248)	Prec 84.375% (85.739%)
# Epoch: [58][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5207 (0.4257)	Prec 87.500% (85.673%)
# Validation starts
# Test: [0/79]	Time 0.078 (0.078)	Loss 0.5768 (0.5768)	Prec 82.031% (82.031%)
#  * Prec 82.080%
# best acc: 82.350000
# Epoch 59 started...
# Epoch: [59][0/391]	Time 0.291 (0.291)	Data 0.268 (0.268)	Loss 0.4227 (0.4227)	Prec 83.594% (83.594%)
# Epoch: [59][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.2756 (0.4162)	Prec 92.188% (85.760%)
# Epoch: [59][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3901 (0.4187)	Prec 86.719% (85.716%)
# Epoch: [59][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4946 (0.4234)	Prec 82.031% (85.696%)
# Validation starts
# Test: [0/79]	Time 0.141 (0.141)	Loss 0.6711 (0.6711)	Prec 78.125% (78.125%)
#  * Prec 79.260%
# best acc: 82.350000
# Epoch 60 started...
# Epoch: [60][0/391]	Time 0.310 (0.310)	Data 0.283 (0.283)	Loss 0.3775 (0.3775)	Prec 86.719% (86.719%)
# Epoch: [60][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.5127 (0.4069)	Prec 85.938% (86.386%)
# Epoch: [60][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3969 (0.4181)	Prec 86.719% (85.976%)
# Epoch: [60][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3920 (0.4197)	Prec 85.156% (85.943%)
# Validation starts
# Test: [0/79]	Time 0.112 (0.112)	Loss 0.6294 (0.6294)	Prec 78.125% (78.125%)
#  * Prec 81.380%
# best acc: 82.350000
# Epoch 61 started...
# Epoch: [61][0/391]	Time 0.234 (0.234)	Data 0.203 (0.203)	Loss 0.3902 (0.3902)	Prec 89.062% (89.062%)
# Epoch: [61][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4412 (0.4114)	Prec 81.250% (86.061%)
# Epoch: [61][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4447 (0.4175)	Prec 85.938% (85.903%)
# Epoch: [61][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.4296 (0.4159)	Prec 85.156% (85.896%)
# Validation starts
# Test: [0/79]	Time 0.252 (0.252)	Loss 0.4181 (0.4181)	Prec 85.156% (85.156%)
#  * Prec 82.360%
# best acc: 82.360000
# Epoch 62 started...
# Epoch: [62][0/391]	Time 0.352 (0.352)	Data 0.321 (0.321)	Loss 0.2772 (0.2772)	Prec 89.844% (89.844%)
# Epoch: [62][100/391]	Time 0.035 (0.038)	Data 0.002 (0.005)	Loss 0.3286 (0.4143)	Prec 88.281% (86.061%)
# Epoch: [62][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 0.5509 (0.4095)	Prec 83.594% (86.225%)
# Epoch: [62][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5298 (0.4099)	Prec 82.031% (86.290%)
# Validation starts
# Test: [0/79]	Time 0.153 (0.153)	Loss 0.5253 (0.5253)	Prec 84.375% (84.375%)
#  * Prec 80.660%
# best acc: 82.360000
# Epoch 63 started...
# Epoch: [63][0/391]	Time 0.306 (0.306)	Data 0.273 (0.273)	Loss 0.3226 (0.3226)	Prec 89.844% (89.844%)
# Epoch: [63][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.4434 (0.3883)	Prec 84.375% (86.997%)
# Epoch: [63][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4957 (0.3996)	Prec 82.812% (86.594%)
# Epoch: [63][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3650 (0.3998)	Prec 88.281% (86.669%)
# Validation starts
# Test: [0/79]	Time 0.121 (0.121)	Loss 0.6664 (0.6664)	Prec 80.469% (80.469%)
#  * Prec 79.780%
# best acc: 82.360000
# Epoch 64 started...
# Epoch: [64][0/391]	Time 0.229 (0.229)	Data 0.196 (0.196)	Loss 0.4602 (0.4602)	Prec 85.156% (85.156%)
# Epoch: [64][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.5114 (0.4049)	Prec 82.812% (86.386%)
# Epoch: [64][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4346 (0.4020)	Prec 85.938% (86.435%)
# Epoch: [64][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5688 (0.4006)	Prec 80.469% (86.547%)
# Validation starts
# Test: [0/79]	Time 0.134 (0.134)	Loss 0.6200 (0.6200)	Prec 82.812% (82.812%)
#  * Prec 81.080%
# best acc: 82.360000
# Epoch 65 started...
# Epoch: [65][0/391]	Time 0.267 (0.267)	Data 0.237 (0.237)	Loss 0.2245 (0.2245)	Prec 90.625% (90.625%)
# Epoch: [65][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.5110 (0.4058)	Prec 82.812% (86.463%)
# Epoch: [65][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4347 (0.4035)	Prec 85.156% (86.571%)
# Epoch: [65][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3543 (0.4047)	Prec 87.500% (86.371%)
# Validation starts
# Test: [0/79]	Time 0.153 (0.153)	Loss 0.4988 (0.4988)	Prec 82.812% (82.812%)
#  * Prec 81.590%
# best acc: 82.360000
# Epoch 66 started...
# Epoch: [66][0/391]	Time 0.411 (0.411)	Data 0.384 (0.384)	Loss 0.2831 (0.2831)	Prec 90.625% (90.625%)
# Epoch: [66][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.4304 (0.3793)	Prec 87.500% (87.067%)
# Epoch: [66][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4789 (0.3853)	Prec 83.594% (86.964%)
# Epoch: [66][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3958 (0.3907)	Prec 86.719% (86.745%)
# Validation starts
# Test: [0/79]	Time 0.147 (0.147)	Loss 0.5329 (0.5329)	Prec 85.938% (85.938%)
#  * Prec 80.820%
# best acc: 82.360000
# Epoch 67 started...
# Epoch: [67][0/391]	Time 0.401 (0.401)	Data 0.374 (0.374)	Loss 0.3163 (0.3163)	Prec 88.281% (88.281%)
# Epoch: [67][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.4359 (0.3795)	Prec 85.938% (87.106%)
# Epoch: [67][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4861 (0.3890)	Prec 85.938% (86.975%)
# Epoch: [67][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3735 (0.3960)	Prec 86.719% (86.895%)
# Validation starts
# Test: [0/79]	Time 0.240 (0.240)	Loss 0.4966 (0.4966)	Prec 85.938% (85.938%)
#  * Prec 82.190%
# best acc: 82.360000
# Epoch 68 started...
# Epoch: [68][0/391]	Time 0.320 (0.320)	Data 0.290 (0.290)	Loss 0.2081 (0.2081)	Prec 89.844% (89.844%)
# Epoch: [68][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.5156 (0.3793)	Prec 82.812% (87.059%)
# Epoch: [68][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4382 (0.3804)	Prec 84.375% (87.150%)
# Epoch: [68][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3155 (0.3809)	Prec 88.281% (87.251%)
# Validation starts
# Test: [0/79]	Time 0.244 (0.244)	Loss 0.4200 (0.4200)	Prec 85.938% (85.938%)
#  * Prec 82.030%
# best acc: 82.360000
# Epoch 69 started...
# Epoch: [69][0/391]	Time 0.470 (0.470)	Data 0.386 (0.386)	Loss 0.2763 (0.2763)	Prec 91.406% (91.406%)
# Epoch: [69][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.3736 (0.3878)	Prec 88.281% (86.587%)
# Epoch: [69][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.3712 (0.3845)	Prec 86.719% (86.968%)
# Epoch: [69][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4811 (0.3862)	Prec 81.250% (86.939%)
# Validation starts
# Test: [0/79]	Time 0.242 (0.242)	Loss 0.3893 (0.3893)	Prec 87.500% (87.500%)
#  * Prec 83.330%
# best acc: 83.330000
# Epoch 70 started...
# Epoch: [70][0/391]	Time 0.321 (0.321)	Data 0.294 (0.294)	Loss 0.3796 (0.3796)	Prec 87.500% (87.500%)
# Epoch: [70][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.3253 (0.3747)	Prec 90.625% (87.283%)
# Epoch: [70][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.4267 (0.3769)	Prec 84.375% (87.216%)
# Epoch: [70][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3052 (0.3832)	Prec 90.625% (87.100%)
# Validation starts
# Test: [0/79]	Time 0.149 (0.149)	Loss 0.4111 (0.4111)	Prec 85.938% (85.938%)
#  * Prec 83.720%
# best acc: 83.720000
# Epoch 71 started...
# Epoch: [71][0/391]	Time 0.295 (0.295)	Data 0.270 (0.270)	Loss 0.2818 (0.2818)	Prec 90.625% (90.625%)
# Epoch: [71][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.2169 (0.3624)	Prec 91.406% (87.732%)
# Epoch: [71][200/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 0.4744 (0.3745)	Prec 85.938% (87.504%)
# Epoch: [71][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.4593 (0.3773)	Prec 86.719% (87.316%)
# Validation starts
# Test: [0/79]	Time 0.157 (0.157)	Loss 0.4783 (0.4783)	Prec 85.156% (85.156%)
#  * Prec 82.320%
# best acc: 83.720000
# Epoch 72 started...
# Epoch: [72][0/391]	Time 0.291 (0.291)	Data 0.260 (0.260)	Loss 0.3609 (0.3609)	Prec 87.500% (87.500%)
# Epoch: [72][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.3010 (0.3654)	Prec 88.281% (87.515%)
# Epoch: [72][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4508 (0.3678)	Prec 82.031% (87.449%)
# Epoch: [72][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3866 (0.3745)	Prec 85.938% (87.248%)
# Validation starts
# Test: [0/79]	Time 0.153 (0.153)	Loss 0.5265 (0.5265)	Prec 82.812% (82.812%)
#  * Prec 81.070%
# best acc: 83.720000
# Epoch 73 started...
# Epoch: [73][0/391]	Time 0.393 (0.393)	Data 0.367 (0.367)	Loss 0.2620 (0.2620)	Prec 92.188% (92.188%)
# Epoch: [73][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.2837 (0.3662)	Prec 90.625% (87.423%)
# Epoch: [73][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.3736 (0.3619)	Prec 89.062% (87.776%)
# Epoch: [73][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.5401 (0.3666)	Prec 82.812% (87.619%)
# Validation starts
# Test: [0/79]	Time 0.239 (0.239)	Loss 0.4120 (0.4120)	Prec 85.938% (85.938%)
#  * Prec 81.930%
# best acc: 83.720000
# Epoch 74 started...
# Epoch: [74][0/391]	Time 0.310 (0.310)	Data 0.277 (0.277)	Loss 0.2502 (0.2502)	Prec 91.406% (91.406%)
# Epoch: [74][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.2278 (0.3378)	Prec 91.406% (88.676%)
# Epoch: [74][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3950 (0.3555)	Prec 87.500% (87.998%)
# Epoch: [74][300/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.4616 (0.3608)	Prec 82.812% (87.814%)
# Validation starts
# Test: [0/79]	Time 0.229 (0.229)	Loss 0.4500 (0.4500)	Prec 86.719% (86.719%)
#  * Prec 82.120%
# best acc: 83.720000
# Epoch 75 started...
# Epoch: [75][0/391]	Time 0.339 (0.339)	Data 0.274 (0.274)	Loss 0.4287 (0.4287)	Prec 81.250% (81.250%)
# Epoch: [75][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.4180 (0.3543)	Prec 86.719% (87.949%)
# Epoch: [75][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.3851 (0.3547)	Prec 89.844% (88.017%)
# Epoch: [75][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.3631 (0.3560)	Prec 89.844% (87.954%)
# Validation starts
# Test: [0/79]	Time 0.120 (0.120)	Loss 0.3644 (0.3644)	Prec 88.281% (88.281%)
#  * Prec 82.890%
# best acc: 83.720000
# Epoch 76 started...
# Epoch: [76][0/391]	Time 0.199 (0.199)	Data 0.119 (0.119)	Loss 0.3780 (0.3780)	Prec 88.281% (88.281%)
# Epoch: [76][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.3860 (0.3554)	Prec 85.938% (88.096%)
# Epoch: [76][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4118 (0.3591)	Prec 84.375% (87.885%)
# Epoch: [76][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3322 (0.3638)	Prec 88.281% (87.689%)
# Validation starts
# Test: [0/79]	Time 0.227 (0.227)	Loss 0.4458 (0.4458)	Prec 88.281% (88.281%)
#  * Prec 82.940%
# best acc: 83.720000
# Epoch 77 started...
# Epoch: [77][0/391]	Time 0.223 (0.223)	Data 0.192 (0.192)	Loss 0.3394 (0.3394)	Prec 91.406% (91.406%)
# Epoch: [77][100/391]	Time 0.035 (0.037)	Data 0.002 (0.003)	Loss 0.3356 (0.3386)	Prec 87.500% (88.730%)
# Epoch: [77][200/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.3511 (0.3507)	Prec 88.281% (88.340%)
# Epoch: [77][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.3573 (0.3582)	Prec 87.500% (88.105%)
# Validation starts
# Test: [0/79]	Time 0.222 (0.222)	Loss 0.4212 (0.4212)	Prec 85.938% (85.938%)
#  * Prec 82.550%
# best acc: 83.720000
# Epoch 78 started...
# Epoch: [78][0/391]	Time 0.310 (0.310)	Data 0.281 (0.281)	Loss 0.4122 (0.4122)	Prec 87.500% (87.500%)
# Epoch: [78][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.3135 (0.3432)	Prec 89.844% (88.792%)
# Epoch: [78][200/391]	Time 0.035 (0.036)	Data 0.002 (0.003)	Loss 0.3690 (0.3508)	Prec 89.844% (88.254%)
# Epoch: [78][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.3348 (0.3560)	Prec 87.500% (87.967%)
# Validation starts
# Test: [0/79]	Time 0.153 (0.153)	Loss 0.4723 (0.4723)	Prec 82.031% (82.031%)
#  * Prec 80.630%
# best acc: 83.720000
# Epoch 79 started...
# Epoch: [79][0/391]	Time 0.297 (0.297)	Data 0.264 (0.264)	Loss 0.4036 (0.4036)	Prec 84.375% (84.375%)
# Epoch: [79][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.2977 (0.3398)	Prec 89.062% (88.753%)
# Epoch: [79][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.2151 (0.3536)	Prec 91.406% (88.242%)
# Epoch: [79][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.2362 (0.3497)	Prec 91.406% (88.354%)
# Validation starts
# Test: [0/79]	Time 0.249 (0.249)	Loss 0.4622 (0.4622)	Prec 82.031% (82.031%)
#  * Prec 82.470%
# best acc: 83.720000
# Epoch 80 started...
# Epoch: [80][0/391]	Time 0.391 (0.391)	Data 0.368 (0.368)	Loss 0.3671 (0.3671)	Prec 86.719% (86.719%)
# Epoch: [80][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.2806 (0.3493)	Prec 92.188% (88.281%)
# Epoch: [80][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.2988 (0.3471)	Prec 88.281% (88.215%)
# Epoch: [80][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4254 (0.3516)	Prec 83.594% (88.133%)
# Validation starts
# Test: [0/79]	Time 0.231 (0.231)	Loss 0.5152 (0.5152)	Prec 82.031% (82.031%)
#  * Prec 81.140%
# best acc: 83.720000
# Epoch 81 started...
# Epoch: [81][0/391]	Time 0.404 (0.404)	Data 0.371 (0.371)	Loss 0.3020 (0.3020)	Prec 89.844% (89.844%)
# Epoch: [81][100/391]	Time 0.035 (0.039)	Data 0.002 (0.005)	Loss 0.2137 (0.3383)	Prec 92.969% (88.730%)
# Epoch: [81][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.2824 (0.3453)	Prec 89.062% (88.332%)
# Epoch: [81][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.3959 (0.3478)	Prec 85.938% (88.292%)
# Validation starts
# Test: [0/79]	Time 0.108 (0.108)	Loss 0.4683 (0.4683)	Prec 86.719% (86.719%)
#  * Prec 84.680%
# best acc: 84.680000
# Epoch 82 started...
# Epoch: [82][0/391]	Time 0.248 (0.248)	Data 0.223 (0.223)	Loss 0.3067 (0.3067)	Prec 89.844% (89.844%)
# Epoch: [82][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.3276 (0.3386)	Prec 89.844% (88.923%)
# Epoch: [82][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.5070 (0.3394)	Prec 82.031% (88.670%)
# Epoch: [82][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.4288 (0.3473)	Prec 88.281% (88.445%)
# Validation starts
# Test: [0/79]	Time 0.163 (0.163)	Loss 0.6805 (0.6805)	Prec 81.250% (81.250%)
#  * Prec 79.680%
# best acc: 84.680000
# Epoch 83 started...
# Epoch: [83][0/391]	Time 0.405 (0.405)	Data 0.372 (0.372)	Loss 0.4372 (0.4372)	Prec 85.938% (85.938%)
# Epoch: [83][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.3078 (0.3434)	Prec 91.406% (88.359%)
# Epoch: [83][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.2414 (0.3367)	Prec 91.406% (88.787%)
# Epoch: [83][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.2727 (0.3384)	Prec 90.625% (88.647%)
# Validation starts
# Test: [0/79]	Time 0.220 (0.220)	Loss 0.3975 (0.3975)	Prec 87.500% (87.500%)
#  * Prec 84.270%
# best acc: 84.680000
# Epoch 84 started...
# Epoch: [84][0/391]	Time 0.306 (0.306)	Data 0.279 (0.279)	Loss 0.3235 (0.3235)	Prec 89.844% (89.844%)
# Epoch: [84][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.2687 (0.3286)	Prec 94.531% (88.846%)
# Epoch: [84][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.4248 (0.3343)	Prec 87.500% (88.767%)
# Epoch: [84][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.4124 (0.3443)	Prec 85.938% (88.434%)
# Validation starts
# Test: [0/79]	Time 0.246 (0.246)	Loss 0.5525 (0.5525)	Prec 81.250% (81.250%)
#  * Prec 80.880%
# best acc: 84.680000
# Epoch 85 started...
# Epoch: [85][0/391]	Time 0.408 (0.408)	Data 0.383 (0.383)	Loss 0.4701 (0.4701)	Prec 85.938% (85.938%)
# Epoch: [85][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.3593 (0.3271)	Prec 86.719% (88.830%)
# Epoch: [85][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.2356 (0.3340)	Prec 92.188% (88.518%)
# ...
# Test: [0/79]	Time 0.272 (0.272)	Loss 0.3403 (0.3403)	Prec 89.844% (89.844%)
#  * Prec 88.080%
# best acc: 88.960000
# Epoch 222 started...
# Epoch: [222][0/391]	Time 0.306 (0.306)	Data 0.281 (0.281)	Loss 0.1002 (0.1002)	Prec 97.656% (97.656%)
# Epoch: [222][100/391]	Time 0.029 (0.038)	Data 0.001 (0.004)	Loss 0.0645 (0.0570)	Prec 97.656% (97.896%)
# Epoch: [222][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0715 (0.0606)	Prec 96.094% (97.839%)
# Epoch: [222][300/391]	Time 0.034 (0.036)	Data 0.001 (0.002)	Loss 0.0362 (0.0613)	Prec 98.438% (97.802%)
# Validation starts
# Test: [0/79]	Time 0.280 (0.280)	Loss 0.3643 (0.3643)	Prec 90.625% (90.625%)
#  * Prec 88.490%
# best acc: 88.960000
# Epoch 223 started...
# Epoch: [223][0/391]	Time 0.215 (0.215)	Data 0.192 (0.192)	Loss 0.0399 (0.0399)	Prec 99.219% (99.219%)
# Epoch: [223][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0648 (0.0499)	Prec 99.219% (98.244%)
# Epoch: [223][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0340 (0.0516)	Prec 99.219% (98.173%)
# Epoch: [223][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0222 (0.0541)	Prec 100.000% (98.142%)
# Validation starts
# Test: [0/79]	Time 0.244 (0.244)	Loss 0.3267 (0.3267)	Prec 92.188% (92.188%)
#  * Prec 87.800%
# best acc: 88.960000
# Epoch 224 started...
# Epoch: [224][0/391]	Time 0.313 (0.313)	Data 0.290 (0.290)	Loss 0.1296 (0.1296)	Prec 94.531% (94.531%)
# Epoch: [224][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0929 (0.0593)	Prec 96.875% (97.989%)
# Epoch: [224][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0495 (0.0550)	Prec 96.875% (98.099%)
# Epoch: [224][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0953 (0.0566)	Prec 96.094% (98.085%)
# Validation starts
# Test: [0/79]	Time 0.232 (0.232)	Loss 0.3305 (0.3305)	Prec 89.062% (89.062%)
#  * Prec 88.530%
# best acc: 88.960000
# Epoch 225 started...
# Epoch: [225][0/391]	Time 0.369 (0.369)	Data 0.308 (0.308)	Loss 0.0299 (0.0299)	Prec 99.219% (99.219%)
# Epoch: [225][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0408 (0.0491)	Prec 98.438% (98.298%)
# Epoch: [225][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0493 (0.0500)	Prec 98.438% (98.243%)
# Epoch: [225][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0331 (0.0474)	Prec 99.219% (98.388%)
# Validation starts
# Test: [0/79]	Time 0.245 (0.245)	Loss 0.3489 (0.3489)	Prec 91.406% (91.406%)
#  * Prec 88.640%
# best acc: 88.960000
# Epoch 226 started...
# Epoch: [226][0/391]	Time 0.218 (0.218)	Data 0.195 (0.195)	Loss 0.0658 (0.0658)	Prec 98.438% (98.438%)
# Epoch: [226][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0124 (0.0412)	Prec 100.000% (98.654%)
# Epoch: [226][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0464 (0.0417)	Prec 99.219% (98.644%)
# Epoch: [226][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0546 (0.0402)	Prec 97.656% (98.689%)
# Validation starts
# Test: [0/79]	Time 0.163 (0.163)	Loss 0.2910 (0.2910)	Prec 90.625% (90.625%)
#  * Prec 88.430%
# best acc: 88.960000
# Epoch 227 started...
# Epoch: [227][0/391]	Time 0.388 (0.388)	Data 0.364 (0.364)	Loss 0.0241 (0.0241)	Prec 99.219% (99.219%)
# Epoch: [227][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.0333 (0.0398)	Prec 99.219% (98.739%)
# Epoch: [227][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.1095 (0.0408)	Prec 97.656% (98.663%)
# Epoch: [227][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0527 (0.0400)	Prec 97.656% (98.643%)
# Validation starts
# Test: [0/79]	Time 0.258 (0.258)	Loss 0.3336 (0.3336)	Prec 87.500% (87.500%)
#  * Prec 88.740%
# best acc: 88.960000
# Epoch 228 started...
# Epoch: [228][0/391]	Time 0.308 (0.308)	Data 0.285 (0.285)	Loss 0.0872 (0.0872)	Prec 97.656% (97.656%)
# Epoch: [228][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0120 (0.0391)	Prec 100.000% (98.631%)
# Epoch: [228][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0210 (0.0377)	Prec 98.438% (98.694%)
# Epoch: [228][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.0324 (0.0372)	Prec 99.219% (98.726%)
# Validation starts
# Test: [0/79]	Time 0.244 (0.244)	Loss 0.2223 (0.2223)	Prec 92.969% (92.969%)
#  * Prec 88.500%
# best acc: 88.960000
# Epoch 229 started...
# Epoch: [229][0/391]	Time 0.336 (0.336)	Data 0.308 (0.308)	Loss 0.0800 (0.0800)	Prec 96.875% (96.875%)
# Epoch: [229][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0182 (0.0344)	Prec 100.000% (98.855%)
# Epoch: [229][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0213 (0.0372)	Prec 99.219% (98.702%)
# Epoch: [229][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.0538 (0.0370)	Prec 97.656% (98.689%)
# Validation starts
# Test: [0/79]	Time 0.249 (0.249)	Loss 0.2510 (0.2510)	Prec 93.750% (93.750%)
#  * Prec 88.660%
# best acc: 88.960000
# Epoch 230 started...
# Epoch: [230][0/391]	Time 0.314 (0.314)	Data 0.290 (0.290)	Loss 0.0166 (0.0166)	Prec 100.000% (100.000%)
# Epoch: [230][100/391]	Time 0.034 (0.038)	Data 0.001 (0.004)	Loss 0.0317 (0.0333)	Prec 98.438% (98.902%)
# Epoch: [230][200/391]	Time 0.035 (0.036)	Data 0.002 (0.003)	Loss 0.0236 (0.0349)	Prec 98.438% (98.861%)
# Epoch: [230][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0411 (0.0354)	Prec 99.219% (98.798%)
# Validation starts
# Test: [0/79]	Time 0.254 (0.254)	Loss 0.4228 (0.4228)	Prec 89.844% (89.844%)
#  * Prec 88.680%
# best acc: 88.960000
# Epoch 231 started...
# Epoch: [231][0/391]	Time 0.358 (0.358)	Data 0.276 (0.276)	Loss 0.0340 (0.0340)	Prec 99.219% (99.219%)
# Epoch: [231][100/391]	Time 0.035 (0.038)	Data 0.002 (0.004)	Loss 0.0201 (0.0352)	Prec 100.000% (98.739%)
# Epoch: [231][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0318 (0.0353)	Prec 98.438% (98.760%)
# Epoch: [231][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0265 (0.0349)	Prec 99.219% (98.783%)
# Validation starts
# Test: [0/79]	Time 0.224 (0.224)	Loss 0.3257 (0.3257)	Prec 90.625% (90.625%)
#  * Prec 88.850%
# best acc: 88.960000
# Epoch 232 started...
# Epoch: [232][0/391]	Time 0.220 (0.220)	Data 0.193 (0.193)	Loss 0.0213 (0.0213)	Prec 99.219% (99.219%)
# Epoch: [232][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0668 (0.0372)	Prec 97.656% (98.724%)
# Epoch: [232][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0302 (0.0344)	Prec 98.438% (98.861%)
# Epoch: [232][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0364 (0.0342)	Prec 98.438% (98.855%)
# Validation starts
# Test: [0/79]	Time 0.254 (0.254)	Loss 0.3398 (0.3398)	Prec 91.406% (91.406%)
#  * Prec 88.360%
# best acc: 88.960000
# Epoch 233 started...
# Epoch: [233][0/391]	Time 0.426 (0.426)	Data 0.402 (0.402)	Loss 0.0643 (0.0643)	Prec 97.656% (97.656%)
# Epoch: [233][100/391]	Time 0.036 (0.039)	Data 0.001 (0.005)	Loss 0.0448 (0.0336)	Prec 98.438% (98.817%)
# Epoch: [233][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0291 (0.0351)	Prec 100.000% (98.764%)
# Epoch: [233][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0349 (0.0345)	Prec 98.438% (98.835%)
# Validation starts
# Test: [0/79]	Time 0.222 (0.222)	Loss 0.2909 (0.2909)	Prec 95.312% (95.312%)
#  * Prec 88.780%
# best acc: 88.960000
# Epoch 234 started...
# Epoch: [234][0/391]	Time 0.215 (0.215)	Data 0.190 (0.190)	Loss 0.0140 (0.0140)	Prec 100.000% (100.000%)
# Epoch: [234][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0226 (0.0327)	Prec 99.219% (98.863%)
# Epoch: [234][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0259 (0.0346)	Prec 99.219% (98.783%)
# Epoch: [234][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.1179 (0.0350)	Prec 96.875% (98.806%)
# Validation starts
# Test: [0/79]	Time 0.258 (0.258)	Loss 0.4037 (0.4037)	Prec 91.406% (91.406%)
#  * Prec 88.620%
# best acc: 88.960000
# Epoch 235 started...
# Epoch: [235][0/391]	Time 0.247 (0.247)	Data 0.192 (0.192)	Loss 0.0533 (0.0533)	Prec 96.094% (96.094%)
# Epoch: [235][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0195 (0.0334)	Prec 99.219% (98.863%)
# Epoch: [235][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0073 (0.0337)	Prec 100.000% (98.900%)
# Epoch: [235][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0084 (0.0336)	Prec 100.000% (98.931%)
# Validation starts
# Test: [0/79]	Time 0.235 (0.235)	Loss 0.3759 (0.3759)	Prec 91.406% (91.406%)
#  * Prec 88.770%
# best acc: 88.960000
# Epoch 236 started...
# Epoch: [236][0/391]	Time 0.214 (0.214)	Data 0.191 (0.191)	Loss 0.0310 (0.0310)	Prec 98.438% (98.438%)
# Epoch: [236][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0109 (0.0318)	Prec 100.000% (98.894%)
# Epoch: [236][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0228 (0.0336)	Prec 98.438% (98.834%)
# Epoch: [236][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0134 (0.0324)	Prec 100.000% (98.887%)
# Validation starts
# Test: [0/79]	Time 0.247 (0.247)	Loss 0.3187 (0.3187)	Prec 91.406% (91.406%)
#  * Prec 88.470%
# best acc: 88.960000
# Epoch 237 started...
# Epoch: [237][0/391]	Time 0.408 (0.408)	Data 0.385 (0.385)	Loss 0.0110 (0.0110)	Prec 99.219% (99.219%)
# Epoch: [237][100/391]	Time 0.035 (0.039)	Data 0.001 (0.005)	Loss 0.0120 (0.0290)	Prec 100.000% (98.979%)
# Epoch: [237][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0768 (0.0316)	Prec 98.438% (98.927%)
# Epoch: [237][300/391]	Time 0.037 (0.036)	Data 0.001 (0.003)	Loss 0.0078 (0.0319)	Prec 100.000% (98.907%)
# Validation starts
# Test: [0/79]	Time 0.242 (0.242)	Loss 0.3648 (0.3648)	Prec 90.625% (90.625%)
#  * Prec 88.880%
# best acc: 88.960000
# Epoch 238 started...
# Epoch: [238][0/391]	Time 0.310 (0.310)	Data 0.286 (0.286)	Loss 0.0338 (0.0338)	Prec 97.656% (97.656%)
# Epoch: [238][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0235 (0.0328)	Prec 99.219% (98.909%)
# Epoch: [238][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0545 (0.0334)	Prec 98.438% (98.799%)
# Epoch: [238][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0218 (0.0339)	Prec 99.219% (98.790%)
# Validation starts
# Test: [0/79]	Time 0.258 (0.258)	Loss 0.2434 (0.2434)	Prec 92.969% (92.969%)
#  * Prec 88.840%
# best acc: 88.960000
# Epoch 239 started...
# Epoch: [239][0/391]	Time 0.299 (0.299)	Data 0.275 (0.275)	Loss 0.0182 (0.0182)	Prec 99.219% (99.219%)
# Epoch: [239][100/391]	Time 0.034 (0.037)	Data 0.001 (0.004)	Loss 0.0055 (0.0338)	Prec 100.000% (98.824%)
# Epoch: [239][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0453 (0.0328)	Prec 98.438% (98.842%)
# Epoch: [239][300/391]	Time 0.034 (0.035)	Data 0.001 (0.002)	Loss 0.0985 (0.0330)	Prec 98.438% (98.829%)
# Validation starts
# Test: [0/79]	Time 0.261 (0.261)	Loss 0.4252 (0.4252)	Prec 89.844% (89.844%)
#  * Prec 88.800%
# best acc: 88.960000
# Epoch 240 started...
# Epoch: [240][0/391]	Time 0.218 (0.218)	Data 0.190 (0.190)	Loss 0.0312 (0.0312)	Prec 98.438% (98.438%)
# Epoch: [240][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0070 (0.0322)	Prec 100.000% (98.762%)
# Epoch: [240][200/391]	Time 0.036 (0.036)	Data 0.001 (0.002)	Loss 0.0072 (0.0326)	Prec 100.000% (98.783%)
# Epoch: [240][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0454 (0.0327)	Prec 96.875% (98.788%)
# Validation starts
# Test: [0/79]	Time 0.147 (0.147)	Loss 0.2165 (0.2165)	Prec 92.969% (92.969%)
#  * Prec 88.930%
# best acc: 88.960000
# Epoch 241 started...
# Epoch: [241][0/391]	Time 0.292 (0.292)	Data 0.266 (0.266)	Loss 0.0437 (0.0437)	Prec 97.656% (97.656%)
# Epoch: [241][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.0134 (0.0318)	Prec 100.000% (98.824%)
# Epoch: [241][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0092 (0.0313)	Prec 100.000% (98.896%)
# Epoch: [241][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.1090 (0.0322)	Prec 96.875% (98.894%)
# Validation starts
# Test: [0/79]	Time 0.243 (0.243)	Loss 0.3612 (0.3612)	Prec 90.625% (90.625%)
#  * Prec 88.490%
# best acc: 88.960000
# Epoch 242 started...
# Epoch: [242][0/391]	Time 0.311 (0.311)	Data 0.288 (0.288)	Loss 0.0545 (0.0545)	Prec 96.875% (96.875%)
# Epoch: [242][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0186 (0.0308)	Prec 99.219% (98.902%)
# Epoch: [242][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0341 (0.0325)	Prec 98.438% (98.853%)
# Epoch: [242][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0283 (0.0323)	Prec 98.438% (98.842%)
# Validation starts
# Test: [0/79]	Time 0.246 (0.246)	Loss 0.3571 (0.3571)	Prec 89.844% (89.844%)
#  * Prec 88.630%
# best acc: 88.960000
# Epoch 243 started...
# Epoch: [243][0/391]	Time 0.395 (0.395)	Data 0.367 (0.367)	Loss 0.0219 (0.0219)	Prec 99.219% (99.219%)
# Epoch: [243][100/391]	Time 0.034 (0.038)	Data 0.001 (0.005)	Loss 0.0165 (0.0297)	Prec 100.000% (99.010%)
# Epoch: [243][200/391]	Time 0.034 (0.036)	Data 0.001 (0.003)	Loss 0.0387 (0.0295)	Prec 97.656% (98.982%)
# Epoch: [243][300/391]	Time 0.038 (0.036)	Data 0.001 (0.003)	Loss 0.0678 (0.0305)	Prec 97.656% (98.959%)
# Validation starts
# Test: [0/79]	Time 0.129 (0.129)	Loss 0.2989 (0.2989)	Prec 92.969% (92.969%)
#  * Prec 88.810%
# best acc: 88.960000
# Epoch 244 started...
# Epoch: [244][0/391]	Time 0.224 (0.224)	Data 0.201 (0.201)	Loss 0.0137 (0.0137)	Prec 99.219% (99.219%)
# Epoch: [244][100/391]	Time 0.035 (0.037)	Data 0.001 (0.004)	Loss 0.0165 (0.0335)	Prec 100.000% (98.793%)
# Epoch: [244][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0051 (0.0319)	Prec 100.000% (98.881%)
# Epoch: [244][300/391]	Time 0.034 (0.036)	Data 0.001 (0.002)	Loss 0.0272 (0.0313)	Prec 99.219% (98.918%)
# Validation starts
# Test: [0/79]	Time 0.247 (0.247)	Loss 0.4103 (0.4103)	Prec 91.406% (91.406%)
#  * Prec 88.640%
# best acc: 88.960000
# Epoch 245 started...
# Epoch: [245][0/391]	Time 0.329 (0.329)	Data 0.306 (0.306)	Loss 0.0233 (0.0233)	Prec 99.219% (99.219%)
# Epoch: [245][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0302 (0.0313)	Prec 98.438% (98.948%)
# Epoch: [245][200/391]	Time 0.034 (0.036)	Data 0.001 (0.003)	Loss 0.0214 (0.0301)	Prec 99.219% (98.951%)
# Epoch: [245][300/391]	Time 0.034 (0.036)	Data 0.001 (0.002)	Loss 0.0328 (0.0313)	Prec 98.438% (98.941%)
# Validation starts
# Test: [0/79]	Time 0.251 (0.251)	Loss 0.4316 (0.4316)	Prec 90.625% (90.625%)
#  * Prec 88.390%
# best acc: 88.960000
# Epoch 246 started...
# Epoch: [246][0/391]	Time 0.223 (0.223)	Data 0.199 (0.199)	Loss 0.0168 (0.0168)	Prec 99.219% (99.219%)
# Epoch: [246][100/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0106 (0.0305)	Prec 100.000% (98.909%)
# Epoch: [246][200/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0119 (0.0296)	Prec 100.000% (98.951%)
# Epoch: [246][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0171 (0.0291)	Prec 99.219% (98.959%)
# Validation starts
# Test: [0/79]	Time 0.223 (0.223)	Loss 0.2974 (0.2974)	Prec 92.969% (92.969%)
#  * Prec 88.680%
# best acc: 88.960000
# Epoch 247 started...
# Epoch: [247][0/391]	Time 0.316 (0.316)	Data 0.293 (0.293)	Loss 0.0087 (0.0087)	Prec 100.000% (100.000%)
# Epoch: [247][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0016 (0.0312)	Prec 100.000% (98.878%)
# Epoch: [247][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0386 (0.0320)	Prec 99.219% (98.865%)
# Epoch: [247][300/391]	Time 0.035 (0.036)	Data 0.001 (0.002)	Loss 0.0613 (0.0323)	Prec 99.219% (98.863%)
# Validation starts
# Test: [0/79]	Time 0.153 (0.153)	Loss 0.3457 (0.3457)	Prec 92.969% (92.969%)
#  * Prec 88.420%
# best acc: 88.960000
# Epoch 248 started...
# Epoch: [248][0/391]	Time 0.400 (0.400)	Data 0.377 (0.377)	Loss 0.0522 (0.0522)	Prec 97.656% (97.656%)
# Epoch: [248][100/391]	Time 0.034 (0.038)	Data 0.001 (0.005)	Loss 0.0237 (0.0307)	Prec 98.438% (98.917%)
# Epoch: [248][200/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0119 (0.0314)	Prec 100.000% (98.853%)
# Epoch: [248][300/391]	Time 0.035 (0.036)	Data 0.001 (0.003)	Loss 0.0155 (0.0303)	Prec 99.219% (98.920%)
# Validation starts
# Test: [0/79]	Time 0.181 (0.181)	Loss 0.4310 (0.4310)	Prec 92.188% (92.188%)
#  * Prec 88.780%
# best acc: 88.960000
# Epoch 249 started...
# Epoch: [249][0/391]	Time 0.324 (0.324)	Data 0.295 (0.295)	Loss 0.0224 (0.0224)	Prec 99.219% (99.219%)
# Epoch: [249][100/391]	Time 0.035 (0.038)	Data 0.001 (0.004)	Loss 0.0495 (0.0341)	Prec 99.219% (98.847%)
# Epoch: [249][200/391]	Time 0.035 (0.037)	Data 0.001 (0.003)	Loss 0.0070 (0.0322)	Prec 100.000% (98.892%)
# Epoch: [249][300/391]	Time 0.035 (0.036)	Data 0.002 (0.002)	Loss 0.0026 (0.0312)	Prec 100.000% (98.941%)
# Validation starts
# Test: [0/79]	Time 0.317 (0.317)	Loss 0.3103 (0.3103)	Prec 90.625% (90.625%)
#  * Prec 89.030%
# best acc: 89.030000

# %% [markdown]
# ### PSUM Recovery and Verification
#
# Here we verify that the `psum_recovered` matches the pre-hooked input for the next layer.
# 1. We hook the input of the **Target Layer** (16->16).
# 2. We hook the input of the **Next Layer** (16->512). This serves as our reference output (post-ReLU).
# 3. We verify that `Conv(quantized_input) -> ReLU` matches the reference.

# %%
# Load Best Model (If available)
model_path = os.path.join(fdir, 'model_best.pth.tar')
if os.path.exists(model_path):
    print(f"=> Loading checkpoint {model_path}")
    checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['state_dict'])
else:
    print("No checkpoint found. Using random weights for demonstration.")

model.eval()

# Indices based on cfg_custom['VGG16_HW6']
# [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 16, '16_no_bn', 512, ...]
# Blocks before: 
# 64 block: 2 layers (idx 0-6 with M)
# 128 block: 2 layers (idx 7-13 with M)
# 256 block: 3 layers (idx 14-23 with M)
# 512 block start:
#   24: Conv(256->16)
#   25: BN
#   26: ReLU
#   27: Conv(16->16) [Target, No BN]
#   28: ReLU
#   29: Conv(16->512)

target_layer_idx = 27
next_layer_idx = 29

print(f"Target Layer: {model.features[target_layer_idx]}")
print(f"Next Layer: {model.features[next_layer_idx]}")

# Hook Setup
class SaveInput:
    def __init__(self):
        self.inputs = []
    def __call__(self, module, module_in):
        self.inputs.append(module_in)
    def clear(self):
        self.inputs = []
        
save_input_target = SaveInput()
save_input_next = SaveInput()

hook_target = model.features[target_layer_idx].register_forward_pre_hook(save_input_target)
hook_next = model.features[next_layer_idx].register_forward_pre_hook(save_input_next)

# Run Inference
dataiter = iter(testloader)
images, labels = next(dataiter)
images = images.cuda() if use_gpu else images

with torch.no_grad():
    model(images)
    
# Get Captured Inputs
x_input = save_input_target.inputs[0][0] # Input to 16->16 layer
x_ref_next = save_input_next.inputs[0][0] # Input to 16->512 layer (Reference Output of 16->16)

print(f"Input shape: {x_input.shape}")
print(f"Reference Output shape: {x_ref_next.shape}")

# Check if quantization was actually performed
# If the model is new and un-trained/un-forwarded, weight_q might be all zeros if initialized that way in __init__
# But in our QuantConv2d_Custom, weight_q is a Parameter initialized to zeros, BUT it is updated in forward().
# Since we just ran model(images), forward() was called, so weight_q should be populated with quantized values.

target_layer = model.features[target_layer_idx]

if not getattr(target_layer, 'is_quantized', False):
    print("WARNING: Layer reports it has not been quantized! Check forward pass logic.")

# PSUM Recovery Calculation
x_quantized = target_layer.act_alq(x_input, target_layer.act_alpha)
weight_q = target_layer.weight_q
output_int_sim = F.conv2d(x_quantized, weight_q, target_layer.bias, target_layer.stride, target_layer.padding, target_layer.dilation, target_layer.groups)
output_recovered = F.relu(output_int_sim)

diff = (output_recovered - x_ref_next).abs().mean()
print(f"Mean Difference: {diff.item()}")

if diff.item() < 1e-3:
    print("SUCCESS: PSUM Recovery Verified!")
else:
    print("WARNING: Difference is high. Check quantization or layer logic.")

hook_target.remove()
hook_next.remove()
# Out:
# => Loading checkpoint ../result/VGG16_HW6_2bit_act_4bit_wgt/model_best.pth.tar
# Target Layer: QuantConv2d_Custom(
#   16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#   (weight_quant): weight_quantize_fn()
# )
# Next Layer: QuantConv2d_Custom(
#   16, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#   (weight_quant): weight_quantize_fn()
# )
# Input shape: torch.Size([128, 16, 4, 4])
# Reference Output shape: torch.Size([128, 16, 4, 4])
# Mean Difference: 0.0
# SUCCESS: PSUM Recovery Verified!
